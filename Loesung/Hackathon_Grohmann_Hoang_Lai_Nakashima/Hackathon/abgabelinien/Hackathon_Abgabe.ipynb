# %% [markdown]
# # Abgabe Hackathon
#
# ## Maschinelles Lernen - WiSe 23/24
#
# ### Abgabe 04.02.2024, 23:55 Uhr

# %% [markdown]
# Ihre Aufgabe während des Hackathons ist die Entwicklung eines Modells zur Voraussage von Hauspreisen anhand von Preisen vergangener Transaktionen auf einem Real-World-Datensatz.
# ---
#
# Die **Trainingsdaten** (Ids `1` bis `2000`), auf denen Sie Ihre Modelle trainiert und validiert haben, haben Sie bereits zu Beginn des Hackathons erhalten.
#
# Hier stellen wir Ihnen nun die **Testdaten** (Ids `2001` bis `2919`) zur Verfügung.
# Bei den Testdaten fehlt die Spalte `Verkaufspreis`. Die Werte dieser Spalte sollen Sie mithilfe Ihres trainierten Modells voraussagen.
#
# ---
#
# Ihre Abgabe (Zip-Archiv) soll folgende **3 Dateien** umfassen:
#
# * **Beschreibung** *(description.txt)*: Kurze Beschreibung Ihres Modells und Ihrer Datenvorverarbeitung
# * **Modell** *(model.ipynb)*: Ausführbarer Quellcode Ihres Modells und Ihrer Datenvorverarbeitung
# * **Predictions** *(predictions.csv)*: Vorhersagen Ihres Modells für alle Testdaten (Ids `2001` bis `2919`) mit Spalten `Id` und `Verkaufspreis`. Das Format soll dem in der Datei `prediction_avg.csv` entsprechen.

# %%
# Eingabedaten (ohne Spalte "Verkaufspreis")
import pandas as pd
test = pd.read_csv("test.csv", sep=',', delimiter=None, header='infer', index_col='Id')
test
# Out:
#      Wohngebiet Nachbarschaft Bedingung1 Bedingung2  Wohnungsklasse  \
# Id
# 2001         WN       Flughaf       Norm       Norm             120
# 2002         WM       Altstad       Norm       Norm             190
# 2003         WN       Altstad       Norm       Norm              50
# 2004         WN        Gallus       Zubr       Norm              70
# 2005         WN       Dornbus       Norm       Norm              20
# ...         ...           ...        ...        ...             ...
# 2915         WN        Höchst       Norm       Norm              20
# 2916         WN       Westend       Norm       Norm              60
# 2917         WN       Sachsen       EbOA       Norm              85
# 2918          D       Schwanh       Norm       Norm              60
# 2919         WN       Hochsch       Norm       Norm              20
#
#      Gebauedetyp Wohnungsstil  Baujahr  Umbaujahr  Hausqualitaet  ...  \
# Id                                                                ...
# ...

# %%
# Beispiel für Predictions (Spalten "Id" und "Verkaufspreis")
example_predictions = pd.read_csv("prediction_avg.csv", sep=',', delimiter=None, header='infer', index_col='Id')
example_predictions
# Out:
#       Verkaufspreis
# Id
# 2001    153708.4206
# 2002    153708.4206
# 2003    153708.4206
# 2004    153708.4206
# 2005    153708.4206
# ...             ...
# 2915    153708.4206
# 2916    153708.4206
# 2917    153708.4206
# 2918    153708.4206
# 2919    153708.4206
#
# [919 rows x 1 columns]

# %%
# Export von Predictions aus Pandas-Dataframe
example_predictions.to_csv('prediction.csv', sep=',', header=True, index=True)

# %% [markdown]
# ---
